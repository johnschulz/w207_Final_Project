# %%
import requests
from bs4 import BeautifulSoup
import bs4
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from io import BytesIO
import re
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g
import datetime
from selenium.webdriver.chrome.options import Options
import numpy as np
import random
from selenium.webdriver import ActionChains
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
scope = ['https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name("../creds.json", scope)
client = gspread.authorize(creds)
sheet = client.open("stock data")
sheet = sheet.worksheet("crypto")
df = pd.DataFrame(sheet.get_all_values())
df.columns = df.iloc[0]
df = df.iloc[1:]
df = df.replace('N/A', np.nan)
df= df.dropna()

# %%
scope = ['https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name("../creds.json", scope)
client = gspread.authorize(creds)
sheet = client.open("stock data1")
sheet = sheet.worksheet("crypto")
df1 = pd.DataFrame(sheet.get_all_values())
df1.columns = df1.iloc[0]
df1 = df1.iloc[1:]
df1 = df1.replace('N/A', np.nan)
df1= df1.dropna()

# %%
allData = df.append(df1)
allData
# Out:
# 0         Symbol          Name Price (Intraday)   Change % Change  \
# 1        BTC-USD   Bitcoin USD        18,409.24   -74.29   -0.40%
# 2        ETH-USD  Ethereum USD           569.41    +3.62   +0.64%
# 3        XRP-USD       XRP USD           0.5742  +0.0030   +0.52%
# 4       USDT-USD    Tether USD           1.0003  -0.0001   -0.01%
# 5        LTC-USD  Litecoin USD            76.71    -0.21   -0.27%
# ...          ...           ...              ...      ...      ...
# 21017   DASH-USD      Dash USD            64.57    -1.69   -2.56%
# 21018  MIOTA-USD      IOTA USD           0.1895  -0.0017   -0.91%
# 21019    VET-USD   VeChain USD           0.0055  -0.0000   -0.82%
# 21020    XEM-USD       NEM USD           0.0335  -0.0000   -0.00%
# 21021    ZEC-USD     Zcash USD            35.10    -0.54   -1.51%
#
# 0     Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 1                                341.802B                   32.801B
# 2                                  64.78B                   15.267B
# 3                                 26.044B                   12.553B
# 4                                 19.759B                   56.357B
# 5                                  5.067B                    4.053B
# ...                                   ...                       ...
# 21017                            598.286M                   456.38M
# 21018                            526.801M                    4.303M
# 21019                            303.171M                   92.798M
# 21020                            301.107M                    3.467M
# 21021                            298.622M                  198.568M
#
# 0     Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# 1                                32.801B            32.801B       18.567M
# 2                                15.267B            15.267B      113.768M
# 3                                12.553B            12.553B       45.355B
# 4                                56.357B            56.357B       19.753B
# 5                                 4.053B             4.053B       66.053M
# ...                                  ...                ...           ...
# 21017                            456.38M            456.38M        9.265M
# 21018                             4.303M             4.303M         2.78B
# 21019                            92.798M            92.798M       55.455B
# 21020                             3.467M             3.467M            9B
# 21021                           198.568M           198.568M        8.509M
#
# 0                          time
# 1      Wed Dec  9 18:00:04 2020
# 2      Wed Dec  9 18:00:04 2020
# 3      Wed Dec  9 18:00:04 2020
# 4      Wed Dec  9 18:00:04 2020
# 5      Wed Dec  9 18:00:04 2020
# ...                         ...
# 21017  Sun Jan 12 22:30:04 2020
# 21018  Sun Jan 12 22:30:04 2020
# 21019  Sun Jan 12 22:30:04 2020
# 21020  Sun Jan 12 22:30:04 2020
# 21021  Sun Jan 12 22:30:04 2020
#
# [25699 rows x 11 columns]

# %%
allData = allData.reset_index()
allData
# Out:
# 0      index     Symbol          Name Price (Intraday)   Change % Change  \
# 0          1    BTC-USD   Bitcoin USD        18,409.24   -74.29   -0.40%
# 1          2    ETH-USD  Ethereum USD           569.41    +3.62   +0.64%
# 2          3    XRP-USD       XRP USD           0.5742  +0.0030   +0.52%
# 3          4   USDT-USD    Tether USD           1.0003  -0.0001   -0.01%
# 4          5    LTC-USD  Litecoin USD            76.71    -0.21   -0.27%
# ...      ...        ...           ...              ...      ...      ...
# 25694  21017   DASH-USD      Dash USD            64.57    -1.69   -2.56%
# 25695  21018  MIOTA-USD      IOTA USD           0.1895  -0.0017   -0.91%
# 25696  21019    VET-USD   VeChain USD           0.0055  -0.0000   -0.82%
# 25697  21020    XEM-USD       NEM USD           0.0335  -0.0000   -0.00%
# 25698  21021    ZEC-USD     Zcash USD            35.10    -0.54   -1.51%
#
# 0     Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 0                                341.802B                   32.801B
# 1                                  64.78B                   15.267B
# 2                                 26.044B                   12.553B
# 3                                 19.759B                   56.357B
# 4                                  5.067B                    4.053B
# ...                                   ...                       ...
# 25694                            598.286M                   456.38M
# 25695                            526.801M                    4.303M
# 25696                            303.171M                   92.798M
# 25697                            301.107M                    3.467M
# 25698                            298.622M                  198.568M
#
# 0     Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# 0                                32.801B            32.801B       18.567M
# 1                                15.267B            15.267B      113.768M
# 2                                12.553B            12.553B       45.355B
# 3                                56.357B            56.357B       19.753B
# 4                                 4.053B             4.053B       66.053M
# ...                                  ...                ...           ...
# 25694                            456.38M            456.38M        9.265M
# 25695                             4.303M             4.303M         2.78B
# 25696                            92.798M            92.798M       55.455B
# 25697                             3.467M             3.467M            9B
# 25698                           198.568M           198.568M        8.509M
#
# 0                          time
# 0      Wed Dec  9 18:00:04 2020
# 1      Wed Dec  9 18:00:04 2020
# 2      Wed Dec  9 18:00:04 2020
# 3      Wed Dec  9 18:00:04 2020
# 4      Wed Dec  9 18:00:04 2020
# ...                         ...
# 25694  Sun Jan 12 22:30:04 2020
# 25695  Sun Jan 12 22:30:04 2020
# 25696  Sun Jan 12 22:30:04 2020
# 25697  Sun Jan 12 22:30:04 2020
# 25698  Sun Jan 12 22:30:04 2020
#
# [25699 rows x 12 columns]

# %%
allData = allData.drop(columns = ['index'])
allData
# Out:
# 0         Symbol          Name Price (Intraday)   Change % Change  \
# 0        BTC-USD   Bitcoin USD        18,409.24   -74.29   -0.40%
# 1        ETH-USD  Ethereum USD           569.41    +3.62   +0.64%
# 2        XRP-USD       XRP USD           0.5742  +0.0030   +0.52%
# 3       USDT-USD    Tether USD           1.0003  -0.0001   -0.01%
# 4        LTC-USD  Litecoin USD            76.71    -0.21   -0.27%
# ...          ...           ...              ...      ...      ...
# 25694   DASH-USD      Dash USD            64.57    -1.69   -2.56%
# 25695  MIOTA-USD      IOTA USD           0.1895  -0.0017   -0.91%
# 25696    VET-USD   VeChain USD           0.0055  -0.0000   -0.82%
# 25697    XEM-USD       NEM USD           0.0335  -0.0000   -0.00%
# 25698    ZEC-USD     Zcash USD            35.10    -0.54   -1.51%
#
# 0     Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 0                                341.802B                   32.801B
# 1                                  64.78B                   15.267B
# 2                                 26.044B                   12.553B
# 3                                 19.759B                   56.357B
# 4                                  5.067B                    4.053B
# ...                                   ...                       ...
# 25694                            598.286M                   456.38M
# 25695                            526.801M                    4.303M
# 25696                            303.171M                   92.798M
# 25697                            301.107M                    3.467M
# 25698                            298.622M                  198.568M
#
# 0     Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# 0                                32.801B            32.801B       18.567M
# 1                                15.267B            15.267B      113.768M
# 2                                12.553B            12.553B       45.355B
# 3                                56.357B            56.357B       19.753B
# 4                                 4.053B             4.053B       66.053M
# ...                                  ...                ...           ...
# 25694                            456.38M            456.38M        9.265M
# 25695                             4.303M             4.303M         2.78B
# 25696                            92.798M            92.798M       55.455B
# 25697                             3.467M             3.467M            9B
# 25698                           198.568M           198.568M        8.509M
#
# 0                          time
# 0      Wed Dec  9 18:00:04 2020
# 1      Wed Dec  9 18:00:04 2020
# 2      Wed Dec  9 18:00:04 2020
# 3      Wed Dec  9 18:00:04 2020
# 4      Wed Dec  9 18:00:04 2020
# ...                         ...
# 25694  Sun Jan 12 22:30:04 2020
# 25695  Sun Jan 12 22:30:04 2020
# 25696  Sun Jan 12 22:30:04 2020
# 25697  Sun Jan 12 22:30:04 2020
# 25698  Sun Jan 12 22:30:04 2020
#
# [25699 rows x 11 columns]

# %%
# allData.to_csv('../crypto.csv',encoding='utf-8', index=False)

# %%
df = allData

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if "," in x:
        x = x.replace(',', '')
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'T' in x:
        if len(x) > 1:
            return float(x.replace('T', '')) * 1000000000
        return 1000000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return float(x)

# %%
df["Total Volume All Currencies (24Hr)"] = [value_to_float(x) for x in df["Total Volume All Currencies (24Hr)"]]
df["Volume in Currency (Since 0:00 UTC)"] = [value_to_float(x) for x in df["Volume in Currency (Since 0:00 UTC)"]]
df["Volume in Currency (24Hr)"] = [value_to_float(x) for x in df["Volume in Currency (24Hr)"]]
df['Circulating Supply'] = [value_to_float(x) for x in df['Circulating Supply']]
df['52 Week Range'] = [value_to_float(x) for x in df['52 Week Range']]

# %%
df['Change'] = [s.replace(',', '').replace('+', '') for s in df['Change']]
df["Price (Intraday)"] = [s.replace(',', '') for s in df["Price (Intraday)"]]

# %%
df['time'] = [datetime.datetime.strptime(s[4:], '%b %d %H:%M:%S %Y') for s in df['time']]

# %%
rbh = ['BSV-USD','BTC-USD', 'BCH-USD','LTC-USD','ETH-USD']

# %%
df = df.astype({'Change': float, "Price (Intraday)": float, "Total Volume All Currencies (24Hr)": float, "Volume in Currency (Since 0:00 UTC)": float, "Volume in Currency (24Hr)": float, 'Circulating Supply':float,'52 Week Range': float})

# %%
df = df.drop(columns = '% Change')

# %%
df['day of week'] = [t.weekday() for t in df['time']]
df
# Out:
# 0         Symbol          Name  Price (Intraday)   Change  \
# 0        BTC-USD   Bitcoin USD        18409.2400 -74.2900
# 1        ETH-USD  Ethereum USD          569.4100   3.6200
# 2        XRP-USD       XRP USD            0.5742   0.0030
# 3       USDT-USD    Tether USD            1.0003  -0.0001
# 4        LTC-USD  Litecoin USD           76.7100  -0.2100
# ...          ...           ...               ...      ...
# 25694   DASH-USD      Dash USD           64.5700  -1.6900
# 25695  MIOTA-USD      IOTA USD            0.1895  -0.0017
# 25696    VET-USD   VeChain USD            0.0055  -0.0000
# 25697    XEM-USD       NEM USD            0.0335  -0.0000
# 25698    ZEC-USD     Zcash USD           35.1000  -0.5400
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 0                             3.418020e+11               3.280100e+10
# 1                             6.478000e+10               1.526700e+10
# 2                             2.604400e+10               1.255300e+10
# 3                             1.975900e+10               5.635700e+10
# 4                             5.067000e+09               4.053000e+09
# ...                                    ...                        ...
# 25694                         5.982860e+08               4.563800e+08
# 25695                         5.268010e+08               4.303000e+06
# 25696                         3.031710e+08               9.279800e+07
# 25697                         3.011070e+08               3.467000e+06
# 25698                         2.986220e+08               1.985680e+08
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 0                            3.280100e+10        3.280100e+10   1.856700e+07
# 1                            1.526700e+10        1.526700e+10   1.137680e+08
# 2                            1.255300e+10        1.255300e+10   4.535500e+10
# 3                            5.635700e+10        5.635700e+10   1.975300e+10
# 4                            4.053000e+09        4.053000e+09   6.605300e+07
# ...                                   ...                 ...            ...
# 25694                        4.563800e+08        4.563800e+08   9.265000e+06
# 25695                        4.303000e+06        4.303000e+06   2.780000e+09
# 25696                        9.279800e+07        9.279800e+07   5.545500e+10
# 25697                        3.467000e+06        3.467000e+06   9.000000e+09
# 25698                        1.985680e+08        1.985680e+08   8.509000e+06
#
# 0                    time  day of week
# 0     2020-12-09 18:00:04            2
# 1     2020-12-09 18:00:04            2
# 2     2020-12-09 18:00:04            2
# 3     2020-12-09 18:00:04            2
# 4     2020-12-09 18:00:04            2
# ...                   ...          ...
# 25694 2020-01-12 22:30:04            6
# 25695 2020-01-12 22:30:04            6
# 25696 2020-01-12 22:30:04            6
# 25697 2020-01-12 22:30:04            6
# 25698 2020-01-12 22:30:04            6
#
# [25699 rows x 11 columns]

# %%
df['hour of day'] = [t.hour for t in df['time']]
df
df = df[df['hour of day'] != 22]

# %%
df['timedelta'] = [(datetime.datetime.now() - x).total_seconds() for x in df['time']]

# %%
df['6 hour diff'] = df.groupby('Symbol')['Price (Intraday)'].diff() * -1

# %%
df['% 6 hour diff'] = df['6 hour diff']/ (df['Price (Intraday)'] - df['6 hour diff']) * 100

# %%
oneHotDOW = pd.get_dummies(df['day of week'],prefix='dow')
oHDOWcols = oneHotDOW.columns

# %%
df[list(oHDOWcols)] = oneHotDOW

# %%
oneHotHOD = pd.get_dummies(df['hour of day'],prefix='hod')
oHHODcols = oneHotHOD.columns

# %%
df[list(oHHODcols )] = oneHotHOD

# %%
dfNoOH = df.iloc[:,:15]
dfNoOH
# Out:
# 0         Symbol          Name  Price (Intraday)   Change  \
# 0        BTC-USD   Bitcoin USD        18409.2400 -74.2900
# 1        ETH-USD  Ethereum USD          569.4100   3.6200
# 2        XRP-USD       XRP USD            0.5742   0.0030
# 3       USDT-USD    Tether USD            1.0003  -0.0001
# 4        LTC-USD  Litecoin USD           76.7100  -0.2100
# ...          ...           ...               ...      ...
# 25674   DASH-USD      Dash USD           64.8100  -1.4600
# 25675  MIOTA-USD      IOTA USD            0.1885  -0.0028
# 25676    VET-USD   VeChain USD            0.0055  -0.0001
# 25677    XEM-USD       NEM USD            0.0334  -0.0001
# 25678    ZEC-USD     Zcash USD           35.0200  -0.6200
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 0                             3.418020e+11               3.280100e+10
# 1                             6.478000e+10               1.526700e+10
# 2                             2.604400e+10               1.255300e+10
# 3                             1.975900e+10               5.635700e+10
# 4                             5.067000e+09               4.053000e+09
# ...                                    ...                        ...
# 25674                         6.004830e+08               4.528090e+08
# 25675                         5.239890e+08               4.328000e+06
# 25676                         3.027000e+08               9.091300e+07
# 25677                         3.003970e+08               3.457000e+06
# 25678                         2.979840e+08               1.997620e+08
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 0                            3.280100e+10        3.280100e+10   1.856700e+07
# 1                            1.526700e+10        1.526700e+10   1.137680e+08
# 2                            1.255300e+10        1.255300e+10   4.535500e+10
# 3                            5.635700e+10        5.635700e+10   1.975300e+10
# 4                            4.053000e+09        4.053000e+09   6.605300e+07
# ...                                   ...                 ...            ...
# 25674                        4.528090e+08        4.528090e+08   9.265000e+06
# 25675                        4.328000e+06        4.328000e+06   2.780000e+09
# 25676                        9.091300e+07        9.091300e+07   5.545500e+10
# 25677                        3.457000e+06        3.457000e+06   9.000000e+09
# 25678                        1.997620e+08        1.997620e+08   8.509000e+06
#
# 0                    time  day of week  hour of day     timedelta  \
# 0     2020-12-09 18:00:04            2           18  1.198126e+04
# 1     2020-12-09 18:00:04            2           18  1.198126e+04
# 2     2020-12-09 18:00:04            2           18  1.198126e+04
# 3     2020-12-09 18:00:04            2           18  1.198126e+04
# 4     2020-12-09 18:00:04            2           18  1.198126e+04
# ...                   ...          ...          ...           ...
# 25674 2020-01-13 00:00:08            0            0  2.867518e+07
# 25675 2020-01-13 00:00:08            0            0  2.867518e+07
# 25676 2020-01-13 00:00:08            0            0  2.867518e+07
# 25677 2020-01-13 00:00:08            0            0  2.867518e+07
# 25678 2020-01-13 00:00:08            0            0  2.867518e+07
#
# 0      6 hour diff  % 6 hour diff
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ...            ...            ...
# 25674       0.4800       0.746153
# 25675      -0.0006      -0.317292
# 25676      -0.0001      -1.785714
# 25677      -0.0001      -0.298507
# 25678       2.2900       6.996639
#
# [25679 rows x 15 columns]

# %%
df = df.drop(columns = 'hour of day')
df = df.drop(columns = 'day of week')

# %%
eth = dfNoOH[dfNoOH['Symbol'] == 'ETH-USD']
eth
# Out:
# 0       Symbol          Name  Price (Intraday)  Change  \
# 1      ETH-USD  Ethereum USD            569.41    3.62
# 21     ETH-USD  Ethereum USD            573.53    0.84
# 41     ETH-USD  Ethereum USD            571.12    7.37
# 61     ETH-USD  Ethereum USD            540.40  -10.48
# 81     ETH-USD  Ethereum USD            548.10   -0.13
# ...        ...           ...               ...     ...
# 25580  ETH-USD  Ethereum USD            149.64    5.51
# 25600  ETH-USD  Ethereum USD            147.27    3.13
# 25620  ETH-USD  Ethereum USD            143.94   -2.85
# 25640  ETH-USD  Ethereum USD            143.64   -3.15
# 25660  ETH-USD  Ethereum USD            143.82   -2.97
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 1                             6.478000e+10               1.526700e+10
# 21                            6.524800e+10               1.586000e+10
# 41                            6.497100e+10               1.791300e+10
# 61                            6.147400e+10               1.482900e+10
# 81                            6.234900e+10               1.537200e+10
# ...                                    ...                        ...
# 25580                         1.635100e+10               9.933000e+09
# 25600                         1.609200e+10               9.062000e+09
# 25620                         1.572700e+10               8.288000e+09
# 25640                         1.569400e+10               8.460000e+09
# 25660                         1.571300e+10               8.418000e+09
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 1                            1.526700e+10        1.526700e+10    113768000.0
# 21                           1.586000e+10        1.586000e+10    113767000.0
# 41                           1.791300e+10        1.791300e+10    113761000.0
# 61                           1.482900e+10        1.482900e+10    113758000.0
# 81                           1.537200e+10        1.537200e+10    113754000.0
# ...                                   ...                 ...            ...
# 25580                        9.933000e+09        9.933000e+09    109271000.0
# 25600                        9.062000e+09        9.062000e+09    109267000.0
# 25620                        8.288000e+09        8.288000e+09    109264000.0
# 25640                        8.460000e+09        8.460000e+09    109261000.0
# 25660                        8.418000e+09        8.418000e+09    109257000.0
#
# 0                    time  day of week  hour of day     timedelta  \
# 1     2020-12-09 18:00:04            2           18  1.198126e+04
# 21    2020-12-09 12:00:44            2           12  3.354126e+04
# 41    2020-12-09 06:00:06            2            6  5.517926e+04
# 61    2020-12-09 00:00:04            2            0  7.678126e+04
# 81    2020-12-08 18:00:03            1           18  9.838226e+04
# ...                   ...          ...          ...           ...
# 25580 2020-01-14 00:00:06            1            0  2.858878e+07
# 25600 2020-01-13 18:00:05            0           18  2.861038e+07
# 25620 2020-01-13 12:00:06            0           12  2.863198e+07
# 25640 2020-01-13 06:00:06            0            6  2.865358e+07
# 25660 2020-01-13 00:00:08            0            0  2.867518e+07
#
# 0      6 hour diff  % 6 hour diff
# 1              NaN            NaN
# 21           -4.12      -0.713235
# 41            2.41       0.423766
# 61           30.72       6.027311
# 81           -7.70      -1.385390
# ...            ...            ...
# 25580         3.78       2.591526
# 25600         2.37       1.635611
# 25620         3.33       2.368253
# 25640         0.30       0.209293
# 25660        -0.18      -0.125000
#
# [1208 rows x 15 columns]

# %%
eth = eth.sort_values('time')

# %%
eth = eth.set_index('time')

# %%
eth = eth.drop(columns=['Change', 'timedelta', '6 hour diff', '% 6 hour diff'])
eth
# Out:
# 0                     Symbol          Name  Price (Intraday)  \
# time
# 2020-01-13 00:00:08  ETH-USD  Ethereum USD            143.82
# 2020-12-09 12:00:44    113767000.0            2           12
# 2020-12-09 18:00:04    113768000.0            2           18
#
# [1208 rows x 10 columns]

# %%
# For simplicity I just take the target variable and the date
cols = ['Price (Intraday)', 'Volume in Currency (Since 0:00 UTC)', 'Volume in Currency (24Hr)',
       'Total Volume All Currencies (24Hr)', 'Circulating Supply',
       '52 Week Range']

# eth = eth[['Price (Intraday)']]

eth = eth[cols]
# Log value
for col in cols:
    eth['log_' + col] = np.log(eth[col])
# Add previous n-values
n = 3
for i in range(n):
    for col in cols:
        eth[col + '_lag_' + str(i+1)] = eth[col].shift(i+1)
        # For simplicity we drop the null values 
        eth.dropna(inplace=True)
        eth['log_' + col + '_lag_' + str(i+1)] = np.log(eth[col + '_lag_' + str(i+1)])
        
        eth['log_' + col + '_difference_' + str(i+1)] = eth['log_' + col] - eth['log_' + col + '_lag_' + str(i+1)]
eth
# Out:
# 0                    Price (Intraday)  Volume in Currency (Since 0:00 UTC)  \
# time
# 2020-02-01 06:00:04            181.78                         1.990800e+10
# 2020-02-01 12:00:04            182.77                         2.001700e+10
# 2020-02-01 18:00:03            182.08                         1.994200e+10
# 2020-02-02 00:00:03            186.45                         2.042100e+10
# 2020-02-02 06:00:03            191.03                         2.092400e+10
# ...                               ...                                  ...
# 2020-12-08 18:00:03            548.10                         6.234900e+10
# 2020-12-09 00:00:04            540.40                         6.147400e+10
# 2020-12-09 06:00:06            571.12                         6.497100e+10
# 2020-12-09 12:00:44            573.53                         6.524800e+10
# 2020-12-09 18:00:04            569.41                         6.478000e+10
#
# 0                    Volume in Currency (24Hr)  \
# time
# 2020-02-01 06:00:04               1.154300e+10
# 2020-02-01 12:00:04               1.163100e+10
# 2020-02-01 18:00:03               1.149000e+10
# 2020-02-02 00:00:03               1.250100e+10
# 2020-02-02 06:00:03               1.362500e+10
# ...                                        ...
# 2020-12-08 18:00:03               1.537200e+10
# 2020-12-09 00:00:04               1.482900e+10
# 2020-12-09 06:00:06               1.791300e+10
# 2020-12-09 12:00:44               1.586000e+10
# 2020-12-09 18:00:04               1.526700e+10
#
# 0                    Total Volume All Currencies (24Hr)  Circulating Supply  \
# time
# 2020-02-01 06:00:04                        1.154300e+10        1.154300e+10
# 2020-02-01 12:00:04                        1.163100e+10        1.163100e+10
# 2020-02-01 18:00:03                        1.149000e+10        1.149000e+10
# 2020-02-02 00:00:03                        1.250100e+10        1.250100e+10
# 2020-02-02 06:00:03                        1.362500e+10        1.362500e+10
# ...                                                 ...                 ...
# 2020-12-08 18:00:03                        1.537200e+10        1.537200e+10
# 2020-12-09 00:00:04                        1.482900e+10        1.482900e+10
# 2020-12-09 06:00:06                        1.791300e+10        1.791300e+10
# 2020-12-09 12:00:44                        1.586000e+10        1.586000e+10
# 2020-12-09 18:00:04                        1.526700e+10        1.526700e+10
#
# 0                    52 Week Range  log_Price (Intraday)  \
# time
# 2020-02-01 06:00:04    109519000.0              5.202797
# 2020-12-09 00:00:04                18.549487                        0.000097
# 2020-12-09 06:00:06                18.549522                        0.000088
# 2020-12-09 12:00:44                18.549549                        0.000114
# 2020-12-09 18:00:04                18.549584                        0.000088
#
# [1136 rows x 66 columns]

# %%
# plt.figure(figsize=(12, 6))
# plt.subplot(1,2,1)
# plt.plot(eth['Price (Intraday)'])
# plt.title('Original Time Series')
# plt.subplot(1,2,2)
# plt.plot(eth.log_difference_1)
# plt.title('Log first difference Time Series')

# %%
inclCols = cols

# %%
newCols = []
for col in inclCols:
    for i in range(2,n+1):
        newCols.append('log_' + col + '_difference_' + str(i))
newCols
# Out:
# ['log_Price (Intraday)_difference_2',
#  'log_Price (Intraday)_difference_3',
#  'log_Volume in Currency (Since 0:00 UTC)_difference_2',
#  'log_Volume in Currency (Since 0:00 UTC)_difference_3',
#  'log_Volume in Currency (24Hr)_difference_2',
#  'log_Volume in Currency (24Hr)_difference_3',
#  'log_Total Volume All Currencies (24Hr)_difference_2',
#  'log_Total Volume All Currencies (24Hr)_difference_3',
#  'log_Circulating Supply_difference_2',
#  'log_Circulating Supply_difference_3',
#  'log_52 Week Range_difference_2',
#  'log_52 Week Range_difference_3']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor

# Forecast difference of log values
X, Y = eth[newCols], eth['log_Price (Intraday)_difference_1']

# Split in train-test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=False, random_state=0)

# Initialize the estimator
mdl_adaboost = AdaBoostRegressor(n_estimators=500, learning_rate=0.05)

# Fit the data
mdl_adaboost.fit(X_train, Y_train)

# Make predictions
pred = mdl_adaboost.predict(X_test)

test_size = X_test.shape[0]
test_size
# Out:
# 228

# %%
test_size = X_test.shape[0]
plt.plot(eth.tail(test_size).index, np.exp(eth.tail(test_size)['log_Price (Intraday)_lag_1']  + pred), label='predicted', color='red')
plt.plot(eth.tail(test_size).index, eth.tail(test_size)['Price (Intraday)'], label='real', color='blue')
plt.legend(loc='best')
plt.title('Predicted vs Real with log difference values')
# Out:
# Text(0.5, 1.0, 'Predicted vs Real with log difference values')

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error

X, Y = np.array(eth[newCols]), np.array(eth['log_Price (Intraday)_difference_1'])

# Initialize a TimeSeriesSplitter
tscv = TimeSeriesSplit(n_splits=5)

# Retrieve log_sales_index and sales_index to unstransform data
eth_log_sales_index = np.array(eth.copy().reset_index()['log_Price (Intraday)_lag_1'])
eth_sales_index = np.array(eth.copy().reset_index()['Price (Intraday)_lag_1'])

# Dict to store metric value at every iteration
metric_iter = {}
for idx, val in enumerate(tscv.split(X)):
        train_i, test_i = val
        X_train, X_test = X[train_i], X[test_i]
        Y_train, Y_test = Y[train_i], Y[test_i]
        # Initialize the estimator
        mdl_adaboost = AdaBoostRegressor(n_estimators=500, learning_rate=0.05)
        # Fit the data
        mdl_adaboost.fit(X_train, Y_train)
        # Make predictions
        pred = mdl_adaboost.predict(X_test)
        # Unstransform predictions
        pred_untransform = [np.exp(val_test + val_pred) for val_test, val_pred in zip(eth_log_sales_index[test_i], pred)]
        # Real value
        real = eth_sales_index[test_i]
        # Store metric
        metric_iter[f'iter_{idx + 1}'] = mean_absolute_error(real, pred_untransform)

# %%
test = pd.DataFrame({'prior': pd.Series(real).shift(), 'pred':list(pred_untransform), 'actual': list(real)}).iloc[1:]
test
# Out:
#       prior        pred  actual
# 1    381.67  403.363096  394.51
# 2    394.51  391.106276  396.32
# 3    396.32  405.124677  395.90
# 4    395.90  422.149560  411.57
# 5    411.57  413.290806  417.02
# ..      ...         ...     ...
# 184  578.37  567.253275  571.55
# 185  571.55  536.500935  548.10
# 186  548.10  553.123518  540.40
# 187  540.40  584.160909  571.12
# 188  571.12  568.401218  573.53
#
# [188 rows x 3 columns]

# %%
print(f'Average MSE error: {np.mean(list(metric_iter.values()))}')
# Out:
# Average MAE error: 4.446219192930945

# %%
accuracy = sum((test['prior'] < test['pred']) & (test['prior'] < test['actual'])) + sum((test['prior'] >= test['pred']) & (test['prior'] >= test['actual'])) / len(test)
accuracy
# Out:
# 66.40957446808511

# %%
newCols1 = []
for col in inclCols:
    for i in range(1,n):
        newCols1.append('log_' + col + '_difference_' + str(i))
# Out:
# ['log_Price (Intraday)_difference_1',
#  'log_Price (Intraday)_difference_2',
#  'log_Volume in Currency (Since 0:00 UTC)_difference_1',
#  'log_Volume in Currency (Since 0:00 UTC)_difference_2',
#  'log_Volume in Currency (24Hr)_difference_1',
#  'log_Volume in Currency (24Hr)_difference_2',
#  'log_Total Volume All Currencies (24Hr)_difference_1',
#  'log_Total Volume All Currencies (24Hr)_difference_2',
#  'log_Circulating Supply_difference_1',
#  'log_Circulating Supply_difference_2',
#  'log_52 Week Range_difference_1',
#  'log_52 Week Range_difference_2']

# %%
valToPred = np.array(eth[newCols1].iloc[-1])

# %%
p1 = mdl_adaboost.predict(valToPred.reshape(-1, len(newCols)))

# %%
np.exp(p1[0])
# Out:
# 0.9917462206621547

# %%
np.exp(p1[0]) + eth['Price (Intraday)'].iloc[-1]
# Out:
# 570.4017462206622

# %%
eth['Price (Intraday)'].iloc[-1]
# Out:
# 569.41

# %%
def timeSeriesPred(symbol, depth, cols):
    data = dfNoOH[dfNoOH['Symbol'] == symbol]
    data = data.sort_values('time')
    data = data.set_index('time')
    data = data.drop(columns=['Change', 'timedelta', '6 hour diff', '% 6 hour diff'])
    data

    data = data[cols]
    for col in cols:
        data['log_' + col] = np.log(data[col])

    n = depth
    for i in range(n):
        for col in cols:
            data[col + '_lag_' + str(i+1)] = data[col].shift(i+1)
            data.dropna(inplace=True)
            data['log_' + col + '_lag_' + str(i+1)] = np.log(data[col + '_lag_' + str(i+1)])

            data['log_' + col + '_difference_' + str(i+1)] = data['log_' + col] - data['log_' + col + '_lag_' + str(i+1)]

    inclCols = cols
    newCols = []
    for col in inclCols:
        for i in range(2,n+1):
            newCols.append('log_' + col + '_difference_' + str(i))  

    from sklearn.model_selection import TimeSeriesSplit
    from sklearn.metrics import mean_absolute_error

    X, Y = np.array(data[newCols]), np.array(data['log_Price (Intraday)_difference_1'])

    tscv = TimeSeriesSplit(n_splits=10)

    data_log_sales_index = np.array(data.copy().reset_index()['log_Price (Intraday)_lag_1'])
    data_sales_index = np.array(data.copy().reset_index()['Price (Intraday)_lag_1'])

    metric_iter = {}
    for idx, val in enumerate(tscv.split(X)):
            train_i, test_i = val
            X_train, X_test = X[train_i], X[test_i]
            Y_train, Y_test = Y[train_i], Y[test_i]
            mdl_adaboost = AdaBoostRegressor(n_estimators=500, learning_rate=0.05)
            mdl_adaboost.fit(X_train, Y_train)
            pred = mdl_adaboost.predict(X_test)
            pred_untransform = [np.exp(val_test + val_pred) for val_test, val_pred in zip(data_log_sales_index[test_i], pred)]
            real = data_sales_index[test_i]
            metric_iter[f'iter_{idx + 1}'] = mean_absolute_error(real, pred_untransform)     
    mse = round(np.mean(list(metric_iter.values())),2)

    test = pd.DataFrame({'prior': pd.Series(real).shift(), 'pred':list(pred_untransform), 'actual': list(real)}).iloc[1:]
    accuracy = (sum((test['prior'] < test['pred']) & (test['prior'] < test['actual'])) + sum((test['prior'] >= test['pred']) & (test['prior'] >= test['actual']))) / len(test)

    newCols1 = []
    for col in inclCols:
        for i in range(1,n):
            newCols1.append('log_' + col + '_difference_' + str(i))
    valToPred = np.array(data[newCols1].iloc[-1])
    p1 = mdl_adaboost.predict(valToPred.reshape(-1, len(newCols)))
    currPrice = str(data['Price (Intraday)'].iloc[-1])

    predPrice = str(round(np.exp(p1[0]) + data['Price (Intraday)'].iloc[-1], 2))

    return [symbol, mse, accuracy, depth, currPrice, predPrice]

# %%
cols = ['Price (Intraday)', 'Volume in Currency (Since 0:00 UTC)', 'Volume in Currency (24Hr)',
           'Total Volume All Currencies (24Hr)', 'Circulating Supply',
           '52 Week Range']

# %%
rbh = ['BSV-USD','BTC-USD', 'BCH-USD','LTC-USD','ETH-USD']

# %%
vals = []
for sym in rbh:
    print(sym)
    for d in range(2,7):
        vals.append(timeSeriesPred(sym, d, cols))
# Out:
# BSV-USD
# BTC-USD
# BCH-USD

# %%
results = pd.DataFrame(vals)
results.columns = ['symbol', 'mse', 'accuracy', 'depth', 'current', 'predicted']
results

# %%
for idx, val in enumerate(tscv.split(X)):
    train_i, test_i = val
    X_train, X_test = X[train_i], X[test_i]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor

# Forecast difference of log values
X, Y = eth[newCols], eth['log_Price (Intraday)_difference_1']

# Split in train-test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=False, random_state=0)

# Initialize the estimator
mdl_adaboost = AdaBoostRegressor(n_estimators=500, learning_rate=0.05)

# Fit the data
mdl_adaboost.fit(X_train, Y_train)

# Make predictions
pred = mdl_adaboost.predict(X_test)

test_size = X_test.shape[0]
test_size

# %%
test_size = X_test.shape[0]
plt.plot(eth.tail(test_size).index, np.exp(eth.tail(test_size)['log_Price (Intraday)_lag_1']  + pred), label='predicted', color='red')
plt.plot(eth.tail(test_size).index, eth.tail(test_size)['Price (Intraday)'], label='real', color='blue')
plt.legend(loc='best')
plt.title('Predicted vs Real with log difference values')
