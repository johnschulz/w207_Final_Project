# %%
import requests
from bs4 import BeautifulSoup
import bs4
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from io import BytesIO
import re
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g
import datetime
from selenium.webdriver.chrome.options import Options
import numpy as np
import random
from selenium.webdriver import ActionChains
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %%
scope = ['https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name("../creds.json", scope)
client = gspread.authorize(creds)
sheet = client.open("stock data")
sheet = sheet.worksheet("crypto")
df = pd.DataFrame(sheet.get_all_values())
df.columns = df.iloc[0]
df = df.iloc[1:]
df = df.replace('N/A', np.nan)
df= df.dropna()

# %%
scope = ['https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name("../creds.json", scope)
client = gspread.authorize(creds)
sheet = client.open("stock data1")
sheet = sheet.worksheet("crypto")
df1 = pd.DataFrame(sheet.get_all_values())
df1.columns = df1.iloc[0]
df1 = df1.iloc[1:]
df1 = df1.replace('N/A', np.nan)
df1= df1.dropna()

# %%
allData = df.append(df1)
allData
# Out:
# 0         Symbol          Name Price (Intraday)   Change % Change  \
# 1        BTC-USD   Bitcoin USD        19,082.17  -317.60   -1.64%
# 2        ETH-USD  Ethereum USD           600.12   -10.64   -1.74%
# 3        XRP-USD       XRP USD           0.6261  -0.0514   -7.59%
# 4       USDT-USD    Tether USD           1.0010  +0.0002   +0.02%
# 5        LTC-USD  Litecoin USD            88.89    +0.05   +0.06%
# ...          ...           ...              ...      ...      ...
# 21017   DASH-USD      Dash USD            64.57    -1.69   -2.56%
# 21018  MIOTA-USD      IOTA USD           0.1895  -0.0017   -0.91%
# 21019    VET-USD   VeChain USD           0.0055  -0.0000   -0.82%
# 21020    XEM-USD       NEM USD           0.0335  -0.0000   -0.00%
# 21021    ZEC-USD     Zcash USD            35.10    -0.54   -1.51%
#
# 0     Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 1                                354.155B                    49.61B
# 2                                 68.208B                   23.675B
# 3                                 28.384B                   17.827B
# 4                                 19.147B                   88.117B
# 5                                  5.866B                    9.772B
# ...                                   ...                       ...
# 21017                            598.286M                   456.38M
# 21018                            526.801M                    4.303M
# 21019                            303.171M                   92.798M
# 21020                            301.107M                    3.467M
# 21021                            298.622M                  198.568M
#
# 0     Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# 1                                 49.61B             49.61B       18.559M
# 2                                23.675B            23.675B      113.656M
# 3                                17.827B            17.827B       45.334B
# 4                                88.117B            88.117B       19.127B
# 5                                 9.772B             9.772B       65.992M
# ...                                  ...                ...           ...
# 21017                            456.38M            456.38M        9.265M
# 21018                             4.303M             4.303M         2.78B
# 21019                            92.798M            92.798M       55.455B
# 21020                             3.467M             3.467M            9B
# 21021                           198.568M           198.568M        8.509M
#
# 0                          time
# 1      Tue Dec  1 12:00:04 2020
# 2      Tue Dec  1 12:00:04 2020
# 3      Tue Dec  1 12:00:04 2020
# 4      Tue Dec  1 12:00:04 2020
# 5      Tue Dec  1 12:00:04 2020
# ...                         ...
# 21017  Sun Jan 12 22:30:04 2020
# 21018  Sun Jan 12 22:30:04 2020
# 21019  Sun Jan 12 22:30:04 2020
# 21020  Sun Jan 12 22:30:04 2020
# 21021  Sun Jan 12 22:30:04 2020
#
# [25039 rows x 11 columns]

# %%
allData = allData.reset_index()
allData
# Out:
# 0      index     Symbol          Name Price (Intraday)   Change % Change  \
# 0          1    BTC-USD   Bitcoin USD        19,082.17  -317.60   -1.64%
# 1          2    ETH-USD  Ethereum USD           600.12   -10.64   -1.74%
# 2          3    XRP-USD       XRP USD           0.6261  -0.0514   -7.59%
# 3          4   USDT-USD    Tether USD           1.0010  +0.0002   +0.02%
# 4          5    LTC-USD  Litecoin USD            88.89    +0.05   +0.06%
# ...      ...        ...           ...              ...      ...      ...
# 25034  21017   DASH-USD      Dash USD            64.57    -1.69   -2.56%
# 25035  21018  MIOTA-USD      IOTA USD           0.1895  -0.0017   -0.91%
# 25036  21019    VET-USD   VeChain USD           0.0055  -0.0000   -0.82%
# 25037  21020    XEM-USD       NEM USD           0.0335  -0.0000   -0.00%
# 25038  21021    ZEC-USD     Zcash USD            35.10    -0.54   -1.51%
#
# 0     Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 0                                354.155B                    49.61B
# 1                                 68.208B                   23.675B
# 2                                 28.384B                   17.827B
# 3                                 19.147B                   88.117B
# 4                                  5.866B                    9.772B
# ...                                   ...                       ...
# 25034                            598.286M                   456.38M
# 25035                            526.801M                    4.303M
# 25036                            303.171M                   92.798M
# 25037                            301.107M                    3.467M
# 25038                            298.622M                  198.568M
#
# 0     Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# 0                                 49.61B             49.61B       18.559M
# 1                                23.675B            23.675B      113.656M
# 2                                17.827B            17.827B       45.334B
# 3                                88.117B            88.117B       19.127B
# 4                                 9.772B             9.772B       65.992M
# ...                                  ...                ...           ...
# 25034                            456.38M            456.38M        9.265M
# 25035                             4.303M             4.303M         2.78B
# 25036                            92.798M            92.798M       55.455B
# 25037                             3.467M             3.467M            9B
# 25038                           198.568M           198.568M        8.509M
#
# 0                          time
# 0      Tue Dec  1 12:00:04 2020
# 1      Tue Dec  1 12:00:04 2020
# 2      Tue Dec  1 12:00:04 2020
# 3      Tue Dec  1 12:00:04 2020
# 4      Tue Dec  1 12:00:04 2020
# ...                         ...
# 25034  Sun Jan 12 22:30:04 2020
# 25035  Sun Jan 12 22:30:04 2020
# 25036  Sun Jan 12 22:30:04 2020
# 25037  Sun Jan 12 22:30:04 2020
# 25038  Sun Jan 12 22:30:04 2020
#
# [25039 rows x 12 columns]

# %%
allData = allData.drop(columns = ['index'])
allData
# Out:
# 0         Symbol          Name Price (Intraday)   Change % Change  \
# 0        BTC-USD   Bitcoin USD        19,082.17  -317.60   -1.64%
# 1        ETH-USD  Ethereum USD           600.12   -10.64   -1.74%
# 2        XRP-USD       XRP USD           0.6261  -0.0514   -7.59%
# 3       USDT-USD    Tether USD           1.0010  +0.0002   +0.02%
# 4        LTC-USD  Litecoin USD            88.89    +0.05   +0.06%
# ...          ...           ...              ...      ...      ...
# 25034   DASH-USD      Dash USD            64.57    -1.69   -2.56%
# 25035  MIOTA-USD      IOTA USD           0.1895  -0.0017   -0.91%
# 25036    VET-USD   VeChain USD           0.0055  -0.0000   -0.82%
# 25037    XEM-USD       NEM USD           0.0335  -0.0000   -0.00%
# 25038    ZEC-USD     Zcash USD            35.10    -0.54   -1.51%
#
# 0     Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 0                                354.155B                    49.61B
# 1                                 68.208B                   23.675B
# 2                                 28.384B                   17.827B
# 3                                 19.147B                   88.117B
# 4                                  5.866B                    9.772B
# ...                                   ...                       ...
# 25034                            598.286M                   456.38M
# 25035                            526.801M                    4.303M
# 25036                            303.171M                   92.798M
# 25037                            301.107M                    3.467M
# 25038                            298.622M                  198.568M
#
# 0     Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# 0                                 49.61B             49.61B       18.559M
# 1                                23.675B            23.675B      113.656M
# 2                                17.827B            17.827B       45.334B
# 3                                88.117B            88.117B       19.127B
# 4                                 9.772B             9.772B       65.992M
# ...                                  ...                ...           ...
# 25034                            456.38M            456.38M        9.265M
# 25035                             4.303M             4.303M         2.78B
# 25036                            92.798M            92.798M       55.455B
# 25037                             3.467M             3.467M            9B
# 25038                           198.568M           198.568M        8.509M
#
# 0                          time
# 0      Tue Dec  1 12:00:04 2020
# 1      Tue Dec  1 12:00:04 2020
# 2      Tue Dec  1 12:00:04 2020
# 3      Tue Dec  1 12:00:04 2020
# 4      Tue Dec  1 12:00:04 2020
# ...                         ...
# 25034  Sun Jan 12 22:30:04 2020
# 25035  Sun Jan 12 22:30:04 2020
# 25036  Sun Jan 12 22:30:04 2020
# 25037  Sun Jan 12 22:30:04 2020
# 25038  Sun Jan 12 22:30:04 2020
#
# [25039 rows x 11 columns]

# %%
# allData.to_csv('../crypto.csv',encoding='utf-8', index=False)

# %%
df = allData

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if "," in x:
        x = x.replace(',', '')
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'T' in x:
        if len(x) > 1:
            return float(x.replace('T', '')) * 1000000000
        return 1000000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return float(x)

# %%
df["Total Volume All Currencies (24Hr)"] = [value_to_float(x) for x in df["Total Volume All Currencies (24Hr)"]]
df["Volume in Currency (Since 0:00 UTC)"] = [value_to_float(x) for x in df["Volume in Currency (Since 0:00 UTC)"]]
df["Volume in Currency (24Hr)"] = [value_to_float(x) for x in df["Volume in Currency (24Hr)"]]
df['Circulating Supply'] = [value_to_float(x) for x in df['Circulating Supply']]
df['52 Week Range'] = [value_to_float(x) for x in df['52 Week Range']]

# %%
df['Change'] = [s.replace(',', '').replace('+', '') for s in df['Change']]
df["Price (Intraday)"] = [s.replace(',', '') for s in df["Price (Intraday)"]]

# %%
df['time'] = [datetime.datetime.strptime(s[4:], '%b %d %H:%M:%S %Y') for s in df['time']]

# %%
rbh = ['BSV-USD','BTC-USD', 'BCH-USD','LTC-USD','ETH-USD']

# %%
df = df.astype({'Change': float, "Price (Intraday)": float, "Total Volume All Currencies (24Hr)": float, "Volume in Currency (Since 0:00 UTC)": float, "Volume in Currency (24Hr)": float, 'Circulating Supply':float,'52 Week Range': float})

# %%
df = df.drop(columns = '% Change')

# %%
list(df['time'])[0].hour
# Out:
# 12

# %%
df['day of week'] = [t.weekday() for t in df['time']]
df
# Out:
# 0         Symbol          Name  Price (Intraday)    Change  \
# 0        BTC-USD   Bitcoin USD        19082.1700 -317.6000
# 1        ETH-USD  Ethereum USD          600.1200  -10.6400
# 2        XRP-USD       XRP USD            0.6261   -0.0514
# 3       USDT-USD    Tether USD            1.0010    0.0002
# 4        LTC-USD  Litecoin USD           88.8900    0.0500
# ...          ...           ...               ...       ...
# 25034   DASH-USD      Dash USD           64.5700   -1.6900
# 25035  MIOTA-USD      IOTA USD            0.1895   -0.0017
# 25036    VET-USD   VeChain USD            0.0055   -0.0000
# 25037    XEM-USD       NEM USD            0.0335   -0.0000
# 25038    ZEC-USD     Zcash USD           35.1000   -0.5400
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 0                             3.541550e+11               4.961000e+10
# 1                             6.820800e+10               2.367500e+10
# 2                             2.838400e+10               1.782700e+10
# 3                             1.914700e+10               8.811700e+10
# 4                             5.866000e+09               9.772000e+09
# ...                                    ...                        ...
# 25034                         5.982860e+08               4.563800e+08
# 25035                         5.268010e+08               4.303000e+06
# 25036                         3.031710e+08               9.279800e+07
# 25037                         3.011070e+08               3.467000e+06
# 25038                         2.986220e+08               1.985680e+08
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 0                            4.961000e+10        4.961000e+10   1.855900e+07
# 1                            2.367500e+10        2.367500e+10   1.136560e+08
# 2                            1.782700e+10        1.782700e+10   4.533400e+10
# 3                            8.811700e+10        8.811700e+10   1.912700e+10
# 4                            9.772000e+09        9.772000e+09   6.599200e+07
# ...                                   ...                 ...            ...
# 25034                        4.563800e+08        4.563800e+08   9.265000e+06
# 25035                        4.303000e+06        4.303000e+06   2.780000e+09
# 25036                        9.279800e+07        9.279800e+07   5.545500e+10
# 25037                        3.467000e+06        3.467000e+06   9.000000e+09
# 25038                        1.985680e+08        1.985680e+08   8.509000e+06
#
# 0                    time  day of week
# 0     2020-12-01 12:00:04            1
# 1     2020-12-01 12:00:04            1
# 2     2020-12-01 12:00:04            1
# 3     2020-12-01 12:00:04            1
# 4     2020-12-01 12:00:04            1
# ...                   ...          ...
# 25034 2020-01-12 22:30:04            6
# 25035 2020-01-12 22:30:04            6
# 25036 2020-01-12 22:30:04            6
# 25037 2020-01-12 22:30:04            6
# 25038 2020-01-12 22:30:04            6
#
# [25039 rows x 11 columns]

# %%
df['hour of day'] = [t.hour for t in df['time']]
df
# Out:
# 0         Symbol          Name  Price (Intraday)    Change  \
# 0        BTC-USD   Bitcoin USD        19082.1700 -317.6000
# 1        ETH-USD  Ethereum USD          600.1200  -10.6400
# 2        XRP-USD       XRP USD            0.6261   -0.0514
# 3       USDT-USD    Tether USD            1.0010    0.0002
# 4        LTC-USD  Litecoin USD           88.8900    0.0500
# ...          ...           ...               ...       ...
# 25034   DASH-USD      Dash USD           64.5700   -1.6900
# 25035  MIOTA-USD      IOTA USD            0.1895   -0.0017
# 25036    VET-USD   VeChain USD            0.0055   -0.0000
# 25037    XEM-USD       NEM USD            0.0335   -0.0000
# 25038    ZEC-USD     Zcash USD           35.1000   -0.5400
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 0                             3.541550e+11               4.961000e+10
# 1                             6.820800e+10               2.367500e+10
# 2                             2.838400e+10               1.782700e+10
# 3                             1.914700e+10               8.811700e+10
# 4                             5.866000e+09               9.772000e+09
# ...                                    ...                        ...
# 25034                         5.982860e+08               4.563800e+08
# 25035                         5.268010e+08               4.303000e+06
# 25036                         3.031710e+08               9.279800e+07
# 25037                         3.011070e+08               3.467000e+06
# 25038                         2.986220e+08               1.985680e+08
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 0                            4.961000e+10        4.961000e+10   1.855900e+07
# 1                            2.367500e+10        2.367500e+10   1.136560e+08
# 2                            1.782700e+10        1.782700e+10   4.533400e+10
# 3                            8.811700e+10        8.811700e+10   1.912700e+10
# 4                            9.772000e+09        9.772000e+09   6.599200e+07
# ...                                   ...                 ...            ...
# 25034                        4.563800e+08        4.563800e+08   9.265000e+06
# 25035                        4.303000e+06        4.303000e+06   2.780000e+09
# 25036                        9.279800e+07        9.279800e+07   5.545500e+10
# 25037                        3.467000e+06        3.467000e+06   9.000000e+09
# 25038                        1.985680e+08        1.985680e+08   8.509000e+06
#
# 0                    time  day of week  hour of day
# 0     2020-12-01 12:00:04            1           12
# 1     2020-12-01 12:00:04            1           12
# 2     2020-12-01 12:00:04            1           12
# 3     2020-12-01 12:00:04            1           12
# 4     2020-12-01 12:00:04            1           12
# ...                   ...          ...          ...
# 25034 2020-01-12 22:30:04            6           22
# 25035 2020-01-12 22:30:04            6           22
# 25036 2020-01-12 22:30:04            6           22
# 25037 2020-01-12 22:30:04            6           22
# 25038 2020-01-12 22:30:04            6           22
#
# [25039 rows x 12 columns]

# %%
df = df[df['hour of day'] != 22]
df
# Out:
# 0         Symbol          Name  Price (Intraday)    Change  \
# 0        BTC-USD   Bitcoin USD        19082.1700 -317.6000
# 1        ETH-USD  Ethereum USD          600.1200  -10.6400
# 2        XRP-USD       XRP USD            0.6261   -0.0514
# 3       USDT-USD    Tether USD            1.0010    0.0002
# 4        LTC-USD  Litecoin USD           88.8900    0.0500
# ...          ...           ...               ...       ...
# 25014   DASH-USD      Dash USD           64.8100   -1.4600
# 25015  MIOTA-USD      IOTA USD            0.1885   -0.0028
# 25016    VET-USD   VeChain USD            0.0055   -0.0001
# 25017    XEM-USD       NEM USD            0.0334   -0.0001
# 25018    ZEC-USD     Zcash USD           35.0200   -0.6200
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 0                             3.541550e+11               4.961000e+10
# 1                             6.820800e+10               2.367500e+10
# 2                             2.838400e+10               1.782700e+10
# 3                             1.914700e+10               8.811700e+10
# 4                             5.866000e+09               9.772000e+09
# ...                                    ...                        ...
# 25014                         6.004830e+08               4.528090e+08
# 25015                         5.239890e+08               4.328000e+06
# 25016                         3.027000e+08               9.091300e+07
# 25017                         3.003970e+08               3.457000e+06
# 25018                         2.979840e+08               1.997620e+08
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 0                            4.961000e+10        4.961000e+10   1.855900e+07
# 1                            2.367500e+10        2.367500e+10   1.136560e+08
# 2                            1.782700e+10        1.782700e+10   4.533400e+10
# 3                            8.811700e+10        8.811700e+10   1.912700e+10
# 4                            9.772000e+09        9.772000e+09   6.599200e+07
# ...                                   ...                 ...            ...
# 25014                        4.528090e+08        4.528090e+08   9.265000e+06
# 25015                        4.328000e+06        4.328000e+06   2.780000e+09
# 25016                        9.091300e+07        9.091300e+07   5.545500e+10
# 25017                        3.457000e+06        3.457000e+06   9.000000e+09
# 25018                        1.997620e+08        1.997620e+08   8.509000e+06
#
# 0                    time  day of week  hour of day
# 0     2020-12-01 12:00:04            1           12
# 1     2020-12-01 12:00:04            1           12
# 2     2020-12-01 12:00:04            1           12
# 3     2020-12-01 12:00:04            1           12
# 4     2020-12-01 12:00:04            1           12
# ...                   ...          ...          ...
# 25014 2020-01-13 00:00:08            0            0
# 25015 2020-01-13 00:00:08            0            0
# 25016 2020-01-13 00:00:08            0            0
# 25017 2020-01-13 00:00:08            0            0
# 25018 2020-01-13 00:00:08            0            0
#
# [25019 rows x 12 columns]

# %%
df['timedelta'] = [(datetime.datetime.now() - x).total_seconds() for x in df['time']]
# Out:
# /Users/johnschulz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['6 hour diff'] = df.groupby('Symbol')['Price (Intraday)'].diff() * -1
# Out:
# /Users/johnschulz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['% 6 hour diff'] = df['6 hour diff']/ (df['Price (Intraday)'] - df['6 hour diff']) * 100
# Out:
# /Users/johnschulz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# min_max_scaler = preprocessing.MinMaxScaler()
# x_scaled = min_max_scaler.fit_transform(x)

# %%
def linRegressionScaled(data):
    data = data.drop(columns = 'time')
    test = data.drop(columns = ['Name', 'Symbol'])
    test = test.dropna()
    X = test.drop(columns = ['% 6 hour diff', '6 hour diff'])
    y = test['% 6 hour diff']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    model = LinearRegression()
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    return y_pred, y_test

# %%
eth = df[df['Symbol'] == 'ETH-USD']
eth
# Out:
# 0       Symbol          Name  Price (Intraday)  Change  \
# 1      ETH-USD  Ethereum USD            600.12  -10.64
# 21     ETH-USD  Ethereum USD            591.49  -19.27
# 41     ETH-USD  Ethereum USD            608.75    1.33
# 61     ETH-USD  Ethereum USD            611.74   -5.37
# 81     ETH-USD  Ethereum USD            602.60   -8.29
# ...        ...           ...               ...     ...
# 24920  ETH-USD  Ethereum USD            149.64    5.51
# 24940  ETH-USD  Ethereum USD            147.27    3.13
# 24960  ETH-USD  Ethereum USD            143.94   -2.85
# 24980  ETH-USD  Ethereum USD            143.64   -3.15
# 25000  ETH-USD  Ethereum USD            143.82   -2.97
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 1                             6.820800e+10               2.367500e+10
# 21                            6.722400e+10               2.558700e+10
# 41                            6.918400e+10               2.290400e+10
# 61                            6.952200e+10               2.220900e+10
# 81                            6.848100e+10               2.236500e+10
# ...                                    ...                        ...
# 24920                         1.635100e+10               9.933000e+09
# 24940                         1.609200e+10               9.062000e+09
# 24960                         1.572700e+10               8.288000e+09
# 24980                         1.569400e+10               8.460000e+09
# 25000                         1.571300e+10               8.418000e+09
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 1                            2.367500e+10        2.367500e+10    113656000.0
# 21                           2.558700e+10        2.558700e+10    113653000.0
# 41                           2.290400e+10        2.290400e+10    113649000.0
# 61                           2.220900e+10        2.220900e+10    113646000.0
# 81                           2.236500e+10        2.236500e+10    113643000.0
# ...                                   ...                 ...            ...
# 24920                        9.933000e+09        9.933000e+09    109271000.0
# 24940                        9.062000e+09        9.062000e+09    109267000.0
# 24960                        8.288000e+09        8.288000e+09    109264000.0
# 24980                        8.460000e+09        8.460000e+09    109261000.0
# 25000                        8.418000e+09        8.418000e+09    109257000.0
#
# 0                    time  day of week  hour of day     timedelta  \
# 1     2020-12-01 12:00:04            1           12  7.313414e+03
# 21    2020-12-01 06:00:04            1            6  2.891341e+04
# 41    2020-12-01 00:00:03            1            0  5.051441e+04
# 61    2020-11-30 18:00:04            0           18  7.211342e+04
# 81    2020-11-30 12:00:05            0           12  9.371242e+04
# ...                   ...          ...          ...           ...
# 24920 2020-01-14 00:00:06            1            0  2.787131e+07
# 24940 2020-01-13 18:00:05            0           18  2.789291e+07
# 24960 2020-01-13 12:00:06            0           12  2.791451e+07
# 24980 2020-01-13 06:00:06            0            6  2.793611e+07
# 25000 2020-01-13 00:00:08            0            0  2.795771e+07
#
# 0      6 hour diff  % 6 hour diff
# 1              NaN            NaN
# 21            8.63       1.480630
# 41          -17.26      -2.757144
# 61           -2.99      -0.486392
# 81            9.14       1.540121
# ...            ...            ...
# 24920         3.78       2.591526
# 24940         2.37       1.635611
# 24960         3.33       2.368253
# 24980         0.30       0.209293
# 25000        -0.18      -0.125000
#
# [1175 rows x 15 columns]

# %%
def linRegression(data, test_size, train_size):
    data = data.drop(columns = 'time')
    test = data.drop(columns = ['Name', 'Symbol'])
    test = test.dropna()
    X = test.drop(columns = ['% 6 hour diff', '6 hour diff'])
    y = test['% 6 hour diff']
    scaler = StandardScaler() 
    X = scaler.fit_transform(X)
    
    X_train = X[test_size:test_size + train_size]
    X_test = X[:test_size]

    
    y_train = y[test_size:test_size + train_size]
    y_test = y[:test_size]
    model = LinearRegression()
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    return y_pred, y_test

# %%
def linRegressionProj(data, test_size, train_size):
    data = data.drop(columns = 'time')
    test = data.drop(columns = ['Name', 'Symbol'])
#     test = test.dropna()
    X = test.drop(columns = ['% 6 hour diff', '6 hour diff'])
    y = test['% 6 hour diff']
    scaler = StandardScaler() 
    X = scaler.fit_transform(X)
    
    X_train = X[test_size:test_size + train_size]
    X_test = X[:test_size]

    
    y_train = y[test_size:test_size + train_size]
    y_test = y[:test_size]
    model = LinearRegression()
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    return y_pred, y_test

# %%
# minR2 = 100000
# ind = 0
# xx = 0
# data = eth
# tests = pd.DataFrame(columns=["test size", "train size", "average accuracy"])

# for x in range(3, 50):
#     for i in range(3, 30):
#         avgr2 = 0
#         p1 = []
#         t1 = []
#         for y in range(0, 10):
#             test = data[y:]
#             p, t = linRegression(test, i, x)
#             r2 = abs(t.iloc[0] - p[0])
#             avgr2 += r2
#         avgr2 = avgr2/100
#         tests = tests.append({"test size": i,
#                         "train size": x,
#                         "average accuracy": avgr2}, ignore_index=True)
#         if minR2 > avgr2:
#             minR2 = avgr2
#             ind = i
#             xx = x
        
            
# ind

# %%
minR2 = 0
ind = 0
xx = 0
data = eth
tests = pd.DataFrame(columns=["test size", "train size", "average accuracy"])
for x in range(1, 350):
    print(x)
    for i in range(1, 150):
        avgr2 = 0
        p1 = []
        t1 = []
        for y in range(1, 100):
            test = data.iloc[y:]
            p, t = linRegression(test, i, x)
            p1.append(p[0])
            t1.append(t.iloc[0])
        avgr2 = metrics.r2_score(t1,p1)
        tests = tests.append({"test size": i,
                        "train size": x,
                        "average accuracy": avgr2}, ignore_index=True)
        if minR2 < avgr2 and avgr2 < 1:
            minR2 = avgr2
            ind = i
            xx = x
            ts = t1
            ps = p1          
ind
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-117a52240039> in <module>
#      12         for y in range(1, 100):
#      13             test = data.iloc[y:]
# ---> 14             p, t = linRegression(test, i, x)
#      15             p1.append(p[0])
#      16             t1.append(t.iloc[0])
#
# <ipython-input-146-e1032cd602f6> in linRegression(data, test_size, train_size)
#       2     data = data.drop(columns = 'time')
#       3     test = data.drop(columns = ['Name', 'Symbol'])
# ----> 4     test = test.dropna()
#       5     X = test.drop(columns = ['% 6 hour diff', '6 hour diff'])
#       6     y = test['% 6 hour diff']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4763                 raise TypeError("must specify how or thresh")
#    4764
# -> 4765         result = self.loc(axis=axis)[mask]
#    4766
#    4767         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911             return self._get_slice_axis(key, axis=axis)
#    1912         elif com.is_bool_indexer(key):
# -> 1913             return self._getbool_axis(key, axis=axis)
#    1914         elif is_list_like_indexer(key):
#    1915
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#    1781         key = check_bool_indexer(labels, key)
#    1782         inds = key.nonzero()[0]
# -> 1783         return self.obj._take_with_is_copy(inds, axis=axis)
#    1784
#    1785     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3393
#    3394         new_data = self._data.take(
# -> 3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#    3397         return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1390                 raise Exception("Indices must be nonzero and less than the axis length")
#    1391
# -> 1392         new_labels = self.axes[axis].take(indexer)
#    1393         return self.reindex_indexer(
#    1394             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#     762                 )
#     763             taken = self.values.take(indices)
# --> 764         return self._shallow_copy(taken)
#     765
#     766     def _assert_take_fillable(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py in _shallow_copy(self, values, **kwargs)
#     109         if values is not None and not self._can_hold_na:
#     110             # Ensure we are not returning an Int64Index with float data:
# --> 111             return self._shallow_copy_with_infer(values=values, **kwargs)
#     112         return super()._shallow_copy(values=values, **kwargs)
#     113
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _shallow_copy_with_infer(self, values, **kwargs)
#     565             except (TypeError, ValueError):
#     566                 pass
# --> 567         return Index(values, **attributes)
#     568
#     569     def _update_inplace(self, result, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     300
#     301         # interval
# --> 302         elif is_interval_dtype(data) or is_interval_dtype(dtype):
#     303             # Delay import for perf. https://github.com/pandas-dev/pandas/pull/31423
#     304             from pandas.core.indexes.interval import IntervalIndex
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_interval_dtype(arr_or_dtype)
#     537     if arr_or_dtype is None:
#     538         return False
# --> 539     return IntervalDtype.is_dtype(arr_or_dtype)
#     540
#     541
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py in is_dtype(cls, dtype)
#    1140             else:
#    1141                 return False
# -> 1142         return super().is_dtype(dtype)
#    1143
#    1144     def __from_arrow__(self, array):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#     245         return cls()
#     246
# --> 247     @classmethod
#     248     def is_dtype(cls, dtype) -> bool:
#     249         """
#
# KeyboardInterrupt:

# %%
tests = tests.sort_values('average accuracy', ascending = False).head(40)
guesses = []
for i in range(40):
    p, t = linRegressionProj(eth, int(list(tests['test size'])[i]), int(list(tests['train size'])[i]))
    predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
    guess = list(predsProj['y_pred'])[0]
    guesses.append(guess)
tests['guess'] = guesses  
tests

# %%
tests = tests.sort_values('average accuracy', ascending = False).head(40)
guesses = []
for i in range(40):
    p, t = linRegressionProj(eth, int(list(tests['test size'])[i]), int(list(tests['train size'])[i]))
    predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
    guess = list(predsProj['y_pred'])[0]
    guesses.append(guess)
tests['guess'] = guesses  
tests
# Out:
#      test size  train size  average accuracy     guess
# 854       19.0       144.0          0.028844  0.052004
# 208       19.0       110.0          0.011741 -0.507078
# 778       19.0       140.0          0.010691  0.141725
# 892       19.0       146.0          0.004060  0.092887
# 873       19.0       145.0          0.003340  0.085159
# 246       19.0       112.0          0.000687 -0.532305
# 835       19.0       143.0         -0.003474  0.001815
# 189       19.0       109.0         -0.003592 -0.503339
# 816       19.0       142.0         -0.004318 -0.015403
# 265       19.0       113.0         -0.004777 -0.545003
# 514        2.0       127.0         -0.010032  0.415551
# 702       19.0       136.0         -0.010721 -0.046538
# 911       19.0       147.0         -0.011133  0.073533
# 797       19.0       141.0         -0.014382 -0.038197
# 227       19.0       111.0         -0.016600 -0.522176
# 303       19.0       115.0         -0.018152 -0.476788
# 759       19.0       139.0         -0.019713  0.156001
# 533        2.0       128.0         -0.021256  0.416022
# 248        2.0       113.0         -0.021442  0.890668
# 799        2.0       142.0         -0.021746  0.516786
# 949       19.0       149.0         -0.021949  0.089309
# 814       17.0       142.0         -0.022243  0.097425
# 930       19.0       148.0         -0.022258  0.102107
# 495        2.0       126.0         -0.024477  0.487085
# 284       19.0       114.0         -0.025052 -0.473253
# 476        2.0       125.0         -0.025859  0.529416
# 628        2.0       133.0         -0.028235  0.572509
# 457        2.0       124.0         -0.030355  0.506627
# 647        2.0       134.0         -0.030392  0.515705
# 894        2.0       147.0         -0.031625  0.631234
# 932        2.0       149.0         -0.031728  0.647004
# 343        2.0       118.0         -0.032181  0.686794
# 419        2.0       122.0         -0.033357  0.587112
# 571        2.0       130.0         -0.034851  0.436500
# 850       15.0       144.0         -0.035566 -0.332393
# 609        2.0       132.0         -0.035732  0.524271
# 723        2.0       138.0         -0.037114  0.520861
# 721       19.0       137.0         -0.037226 -0.086627
# 856        2.0       145.0         -0.038533  0.502869
# 666        2.0       135.0         -0.039248  0.522103

# %%
tests = tests.sort_values('average accuracy', ascending = False).head(40)
tests
# Out:
#      test size  train size  average accuracy
# 894        2.0        97.0         -0.080238
# 932        2.0        99.0         -0.081492
# 913        2.0        98.0         -0.082241
# 875        2.0        96.0         -0.120970
# 912        1.0        98.0         -0.121097
# 931        1.0        99.0         -0.126856
# 799        2.0        92.0         -0.133444
# 856        2.0        95.0         -0.135335
# 818        2.0        93.0         -0.144702
# 837        2.0        94.0         -0.147251
# 780        2.0        91.0         -0.148081
# 761        2.0        90.0         -0.161424
# 836        1.0        94.0         -0.165527
# 817        1.0        93.0         -0.168398
# 742        2.0        89.0         -0.175935
# 933        3.0        99.0         -0.179338
# 914        3.0        98.0         -0.180537
# 893        1.0        97.0         -0.181654
# 779        1.0        91.0         -0.183236
# 874        1.0        96.0         -0.183850
# 798        1.0        92.0         -0.184106
# 723        2.0        88.0         -0.184825
# 855        1.0        95.0         -0.188525
# 760        1.0        90.0         -0.193642
# 741        1.0        89.0         -0.196192
# 704        2.0        87.0         -0.211145
# 934        4.0        99.0         -0.214423
# 915        4.0        98.0         -0.221905
# 895        3.0        97.0         -0.225490
# 876        3.0        96.0         -0.233613
# 722        1.0        88.0         -0.237893
# 685        2.0        86.0         -0.238520
# 703        1.0        87.0         -0.242295
# 896        4.0        97.0         -0.251657
# 684        1.0        86.0         -0.260650
# 666        2.0        85.0         -0.264403
# 665        1.0        85.0         -0.264558
# 916        5.0        98.0         -0.270271
# 935        5.0        99.0         -0.276208
# 857        3.0        95.0         -0.277468

# %%
guesses = []
for i in range(40):
    p, t = linRegressionProj(eth, int(list(tests['test size'])[i]), int(list(tests['train size'])[i]))
    predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
    guess = list(predsProj['y_pred'])[0]
    guesses.append(guess)
tests['guess'] = guesses  
tests
# Out:
#      test size  train size  average accuracy     guess
# 798        1.0        46.0         -0.440056  0.937467
# 817        1.0        47.0         -0.457188  0.898771
# 722        1.0        42.0         -0.463598  0.892462
# 741        1.0        43.0         -0.469326  0.891479
# 836        1.0        48.0         -0.473080  0.757628
# 779        1.0        45.0         -0.479165  0.950600
# 760        1.0        44.0         -0.481684  1.077693
# 703        1.0        41.0         -0.498541  0.908080
# 855        1.0        49.0         -0.503857  0.798632
# 684        1.0        40.0         -0.519159  1.829514
# 665        1.0        39.0         -0.545487  0.937746
# 856        2.0        49.0         -0.577197  0.755808
# 646        1.0        38.0         -0.588835  0.906051
# 799        2.0        46.0         -0.596805  0.908553
# 780        2.0        45.0         -0.605323  0.950166
# 818        2.0        47.0         -0.619186  0.735856
# 627        1.0        37.0         -0.628915  0.912762
# 704        2.0        41.0         -0.644635  0.829046
# 723        2.0        42.0         -0.654675  0.839140
# 761        2.0        44.0         -0.663403  0.973486
# 742        2.0        43.0         -0.665641  1.050254
# 837        2.0        48.0         -0.668399  0.751144
# 608        1.0        36.0         -0.677898  0.954674
# 589        1.0        35.0         -0.697457  1.196809
# 685        2.0        40.0         -0.720365  0.844880
# 666        2.0        39.0         -0.795203  0.840813
# 570        1.0        34.0         -0.796308  0.353596
# 647        2.0        38.0         -0.847219  0.885545
# 628        2.0        37.0         -0.932733  0.855973
# 551        1.0        33.0         -0.949429  0.361352
# 857        3.0        49.0         -1.011258  0.154596
# 532        1.0        32.0         -1.042967  0.749548
# 609        2.0        36.0         -1.077134  0.856624
# 838        3.0        48.0         -1.084137  0.331097
# 494        1.0        30.0         -1.137572  0.631421
# 590        2.0        35.0         -1.157447  0.887162
# 800        3.0        46.0         -1.169051  0.315130
# 781        3.0        45.0         -1.186253  0.591936
# 513        1.0        31.0         -1.191760  0.721090
# 762        3.0        44.0         -1.210516  0.623058

# %%
predss = pd.DataFrame({'y_pred':ps, 'y_test':ts})
predss
# Out:
#       y_pred    y_test
# 0   2.650727 -0.486392
# 1   0.785796  1.540121
# 2  -0.280781 -0.135708
# 3   0.606125  3.028332
# 4  -1.399305 -0.392668
# 5   1.511443  7.025058
# 6  -0.556322 -0.219939
# 7  -0.029427  2.201305
# 8  -1.887594  1.609800
# 9   0.819483 -2.054942
# 10  3.210035  3.508358
# 11  0.423683  2.246812
# 12  0.034464 -0.792136
# 13  0.729688  2.541396
# 14  1.374992 -0.940221
# 15  0.211930 -1.059030
# 16  1.392537 -2.038623
# 17  0.688234  5.870539
# 18 -2.547852 -3.152420
# 19 -0.515766  0.352113
# 20  0.078543 -8.548286
# 21  0.032722 -3.052604
# 22 -0.028334 -1.222064
# 23 -1.472673  0.166970
# 24 -0.865253 -1.613140
# 25 -0.455629 -0.703754
# 26  0.711384  0.685114
# 27  2.057412 -0.143624
# 28 -0.866421 -2.157682
# 29  1.802044  3.829284
# 30 -1.133315 -0.123746
# 31 -0.600588  2.830556
# 32  1.206657  3.912221
# 33 -2.078232 -1.943963
# 34  1.919748  8.162019
# 35 -0.376045 -1.703203
# 36 -0.175101  0.380108
# 37  3.335643 -0.419665
# 38  0.310405  3.619497
# 39 -0.641934  2.574676
# 40  0.492711 -0.842507
# 41  0.184257  0.802055
# 42  0.268338  0.399036
# 43 -0.352820  3.727430
# 44 -1.695172  2.650727
# 45  0.787419  0.785796
# 46  1.674504 -0.280781
# 47  1.549089  0.606125
# 48 -0.930609 -1.399305

# %%
p, t = linRegressionProj(eth, ind, xx)

# %%
# p1.append(p[0])
p[0]
# Out:
# -0.3075928043584826

# %%
predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
predsProj
# Out:
#        y_pred    y_test
# 1   -0.307593       NaN
# 21  -0.670255 -0.486392
# 41  -0.537400  1.540121
# 61  -0.398921 -0.135708
# 81  -0.340720  3.028332
# 101 -0.303573 -0.392668
# 121  0.285774  7.025058
# 141  0.449635 -0.219939
# 161  0.553138  2.201305
# 181  0.475892  1.609800
# 201  0.436392 -2.054942
# 221  0.715718  3.508358
# 241  0.887085  2.246812
# 261  0.716804 -0.792136
# 281  0.963822  2.541396
# 301  1.151076 -0.940221
# 321  1.258213 -1.059030
# 341  1.148023 -2.038623
# 361  1.594595  5.870539
# 381  1.290527 -3.152420
# 401  0.816161  0.352113
# 421 -0.581763 -8.548286
# 441 -1.096118 -3.052604
# 461 -1.206634 -1.222064
# 481 -1.025713  0.166970
# 501 -1.443297 -1.613140
# 521 -1.451298 -0.703754
# 541 -0.981106  0.685114
# 561 -1.087515 -0.143624
# 581 -1.578111 -2.157682
# 601 -1.126343  3.829284
# 621 -0.999354 -0.123746
# 641 -1.032676  2.830556
# 661 -0.426152  3.912221
# 681 -0.470598 -1.943963
# 701  0.282653  8.162019
# 721 -0.139254 -1.703203
# 741 -0.240477  0.380108
# 761 -0.290730 -0.419665
# 781  0.046630  3.619497
# 801  0.286435  2.574676
# 821 -0.054478 -0.842507
# 841  0.166394  0.802055
# 861  0.248698  0.399036
# 881  0.396367  3.727430
# 901  0.307671  2.650727
# 921  0.392988  0.785796
# 941  0.556081 -0.280781

# %%
qs = list(eth['% 6 hour diff'].quantile([0.1,.2,.3,.4,0.5,0.6,.7,.8,.9]))
qs
# Out:
# [-1.8929820866564373,
#  -0.9960931872495826,
#  -0.5407557610110596,
#  -0.15047714422367334,
#  0.15581387776591138,
#  0.4373120651622644,
#  0.825124650108644,
#  1.4611597105598408,
#  2.5999304306784365]

# %%
quartile = []
for x in eth['% 6 hour diff']:
    if x < qs[0]:
        quartile.append(0)
    elif x < qs[1]:
        quartile.append(1)
    elif x < qs[2]:
        quartile.append(2)
    elif x < qs[3]:
        quartile.append(3)
    elif x < qs[4]:
        quartile.append(4)
    elif x < qs[5]:
        quartile.append(5)
    elif x < qs[6]:
        quartile.append(6)
    elif x < qs[7]:
        quartile.append(7)
    elif x < qs[8]:
        quartile.append(8)
    else:
        quartile.append(9)

# %%
eth['quartile'] = quartile
# Out:
# /Users/johnschulz/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
eth
# Out:
# 0       Symbol          Name  Price (Intraday)  Change  \
# 1      ETH-USD  Ethereum USD            600.12  -10.64
# 21     ETH-USD  Ethereum USD            591.49  -19.27
# 41     ETH-USD  Ethereum USD            608.75    1.33
# 61     ETH-USD  Ethereum USD            611.74   -5.37
# 81     ETH-USD  Ethereum USD            602.60   -8.29
# ...        ...           ...               ...     ...
# 24920  ETH-USD  Ethereum USD            149.64    5.51
# 24940  ETH-USD  Ethereum USD            147.27    3.13
# 24960  ETH-USD  Ethereum USD            143.94   -2.85
# 24980  ETH-USD  Ethereum USD            143.64   -3.15
# 25000  ETH-USD  Ethereum USD            143.82   -2.97
#
# 0      Volume in Currency (Since 0:00 UTC)  Volume in Currency (24Hr)  \
# 1                             6.820800e+10               2.367500e+10
# 21                            6.722400e+10               2.558700e+10
# 41                            6.918400e+10               2.290400e+10
# 61                            6.952200e+10               2.220900e+10
# 81                            6.848100e+10               2.236500e+10
# ...                                    ...                        ...
# 24920                         1.635100e+10               9.933000e+09
# 24940                         1.609200e+10               9.062000e+09
# 24960                         1.572700e+10               8.288000e+09
# 24980                         1.569400e+10               8.460000e+09
# 25000                         1.571300e+10               8.418000e+09
#
# 0      Total Volume All Currencies (24Hr)  Circulating Supply  52 Week Range  \
# 1                            2.367500e+10        2.367500e+10    113656000.0
# 21                           2.558700e+10        2.558700e+10    113653000.0
# 41                           2.290400e+10        2.290400e+10    113649000.0
# 61                           2.220900e+10        2.220900e+10    113646000.0
# 81                           2.236500e+10        2.236500e+10    113643000.0
# ...                                   ...                 ...            ...
# 24920                        9.933000e+09        9.933000e+09    109271000.0
# 24940                        9.062000e+09        9.062000e+09    109267000.0
# 24960                        8.288000e+09        8.288000e+09    109264000.0
# 24980                        8.460000e+09        8.460000e+09    109261000.0
# 25000                        8.418000e+09        8.418000e+09    109257000.0
#
# 0                    time  day of week  hour of day     timedelta  \
# 1     2020-12-01 12:00:04            1           12  7.313414e+03
# 21    2020-12-01 06:00:04            1            6  2.891341e+04
# 41    2020-12-01 00:00:03            1            0  5.051441e+04
# 61    2020-11-30 18:00:04            0           18  7.211342e+04
# 81    2020-11-30 12:00:05            0           12  9.371242e+04
# ...                   ...          ...          ...           ...
# 24920 2020-01-14 00:00:06            1            0  2.787131e+07
# 24940 2020-01-13 18:00:05            0           18  2.789291e+07
# 24960 2020-01-13 12:00:06            0           12  2.791451e+07
# 24980 2020-01-13 06:00:06            0            6  2.793611e+07
# 25000 2020-01-13 00:00:08            0            0  2.795771e+07
#
# 0      6 hour diff  % 6 hour diff  quartile
# 1              NaN            NaN         9
# 21            8.63       1.480630         8
# 41          -17.26      -2.757144         0
# 61           -2.99      -0.486392         3
# 81            9.14       1.540121         8
# ...            ...            ...       ...
# 24920         3.78       2.591526         8
# 24940         2.37       1.635611         8
# 24960         3.33       2.368253         8
# 24980         0.30       0.209293         5
# 25000        -0.18      -0.125000         4
#
# [1175 rows x 16 columns]

# %%
def knn(data, k, test_size, train_size, guess):
    
    data = data.drop(columns = 'time')
    test = data.drop(columns = ['Name', 'Symbol'])
    if not guess:
        test = test.dropna()
    X = test.drop(columns = ['% 6 hour diff', '6 hour diff'])
    y = test['quartile'].astype(int)
    scaler = StandardScaler() 
    X = scaler.fit_transform(X)
    
    X_train = X[test_size:test_size + train_size]
    X_test = X[:test_size]

    
    y_train = y[test_size:test_size + train_size]
    y_test = y[:test_size]
    
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    return y_pred, y_test

# %%
minR2 = 0
ind = 0
xx = 0
data = eth
tests = pd.DataFrame(columns=["test size", "train size", "k neighbors", "average accuracy",])
# for k in range(1,12):
for x in range(65, 150):
    print(x)
    for i in range(20, 40):
        avgr2 = 0
        p1 = []
        t1 = []
        for y in range(1, 100):
            test = data.iloc[y:]
            p, t = knn(test, k, i, x, False)
            p1.append(p[0])
            t1.append(t.iloc[0])
        avgr2 = metrics.accuracy_score(t1,p1)
        tests = tests.append({"test size": i,
                        "train size": x,
                        "k neighbors": k,
                        "average accuracy": avgr2}, ignore_index=True)
        if minR2 < avgr2 and avgr2 < 1:
            minR2 = avgr2
            ind = i
            xx = x
            ts = t1
            ps = p1          
ind
# Out:
# 65
# 66
# 67
# 68

# %%
len(list(tests['test size']))

# %%
qs[2]

# %%
tests = tests.sort_values('average accuracy', ascending = False).head(40)
guesses = []
for i in range(40):
    p, t = knn(eth, int(list(tests["k neighbors"])[i]), int(list(tests['test size'])[i]), int(list(tests['train size'])[i]), True)
    predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
    guess = list(predsProj['y_pred'])[0]
    guesses.append(guess)
tests['guess'] = guesses  
tests

# %%
p, t = knn(eth, 5,30, 71, True)
predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
guess = list(predsProj['y_pred'])[0]
guess
# Out:
# 9

# %%
tests = tests.sort_values('average accuracy', ascending = False).head(40)
guesses = []
for i in range(40):
    p, t = knn(eth, int(list(tests['test size'])[i]), int(list(tests['train size'])[i]), True)
    predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
    guess = list(predsProj['y_pred'])[0]
    guesses.append(guess)
tests['guess'] = guesses  
tests
# Out:
#       test size  train size  average accuracy  guess
# 955        25.0        69.0          0.489796      9
# 1200       25.0        74.0          0.489796      9
# 1053       25.0        71.0          0.489796      9
# 1102       25.0        72.0          0.489796      9
# 1151       25.0        73.0          0.489796      9
# 906        25.0        68.0          0.489796      9
# 1249       25.0        75.0          0.489796      9
# 1004       25.0        70.0          0.489796      9
# 1298       25.0        76.0          0.489796      9
# 1543       25.0        81.0          0.469388      9
# 808        25.0        66.0          0.469388      9
# 1690       25.0        84.0          0.469388      9
# 715        30.0        64.0          0.469388      9
# 1347       25.0        77.0          0.469388      9
# 759        25.0        65.0          0.469388      9
# 862        30.0        67.0          0.469388      9
# 813        30.0        66.0          0.469388      9
# 857        25.0        67.0          0.469388      9
# 1641       25.0        83.0          0.469388      9
# 666        30.0        63.0          0.469388      9
# 911        30.0        68.0          0.469388      9
# 1592       25.0        82.0          0.469388      9
# 1739       25.0        85.0          0.469388      9
# 960        30.0        69.0          0.469388      9
# 1494       25.0        80.0          0.469388      9
# 764        30.0        65.0          0.469388      9
# 1445       25.0        79.0          0.469388      9
# 1396       25.0        78.0          0.469388      9
# 1250       26.0        75.0          0.448980      9
# 1788       25.0        86.0          0.448980      9
# 864        32.0        67.0          0.448980      9
# 863        31.0        67.0          0.448980      9
# 1984       25.0        90.0          0.448980      9
# 861        29.0        67.0          0.448980      4
# 860        28.0        67.0          0.448980      4
# 1106       29.0        72.0          0.448980      4
# 859        27.0        67.0          0.448980      9
# 858        26.0        67.0          0.448980      9
# 1105       28.0        72.0          0.448980      4
# 568        30.0        61.0          0.448980      9

# %%
tests = tests.sort_values('average accuracy', ascending = False).head(40)
guesses = []
for i in range(40):
    p, t = knn(eth, int(list(tests['test size'])[i]), int(list(tests['train size'])[i]), True)
    predsProj = pd.DataFrame({'y_pred':p, 'y_test':t})
    guess = list(predsProj['y_pred'])[0]
    guesses.append(guess)
tests['guess'] = guesses  
tests
# Out:
#       test size  train size  average accuracy  guess
# 2129       23.0        48.0          0.367347      9
# 2081       24.0        47.0          0.367347      9
# 1983       24.0        45.0          0.346939      9
# 2108        2.0        48.0          0.346939      9
# 2177       22.0        49.0          0.346939      9
# 2176       21.0        49.0          0.346939      9
# 2032       24.0        46.0          0.346939      9
# 1982       23.0        45.0          0.346939      9
# 952        22.0        24.0          0.346939      9
# 2157        2.0        49.0          0.346939      9
# 1933       23.0        44.0          0.346939      9
# 2010        2.0        46.0          0.346939      9
# 1961        2.0        45.0          0.346939      9
# 903        22.0        23.0          0.346939      9
# 2127       21.0        48.0          0.346939      9
# 2128       22.0        48.0          0.346939      9
# 2178       23.0        49.0          0.346939      9
# 2031       23.0        46.0          0.346939      9
# 1912        2.0        44.0          0.346939      9
# 2079       22.0        47.0          0.346939      9
# 1863        2.0        43.0          0.346939      9
# 2187       32.0        49.0          0.346939      9
# 2059        2.0        47.0          0.346939      9
# 2080       23.0        47.0          0.346939      9
# 1642       26.0        38.0          0.326531      9
# 2131       25.0        48.0          0.326531      9
# 2130       24.0        48.0          0.326531      9
# 1638       22.0        38.0          0.326531      9
# 1350       28.0        32.0          0.326531      4
# 1686       21.0        39.0          0.326531      9
# 2126       20.0        48.0          0.326531      9
# 2125       19.0        48.0          0.326531      9
# 1737       23.0        40.0          0.326531      9
# 1687       22.0        39.0          0.326531      9
# 1688       23.0        39.0          0.326531      9
# 1001       22.0        25.0          0.326531      9
# 1590       23.0        37.0          0.326531      9
# 1736       22.0        40.0          0.326531      9
# 2078       21.0        47.0          0.326531      9
# 1735       21.0        40.0          0.326531      9

# %%
p, t  = knn(eth, 20,100)

# %%
metrics.accuracy_score(t, p)
# Out:
# 0.7

# %%
def logRegression(data, cutoff):
    data = data.drop(columns = 'time')
    test = data.drop(columns = ['Name', 'Symbol'])
    
    valTest = test.iloc[0:1, :]
    test = test.dropna()
    winner = test['% 6 hour diff'] > cutoff
    
    X = test.drop(columns = ['% 6 hour diff', '6 hour diff'])
    valTest = valTest.drop(columns = ['% 6 hour diff', '6 hour diff'])
    y1 = test['% 6 hour diff']
    y = winner
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    X1_train, X1_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.33, random_state=42)
    model = LogisticRegression()
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    
    
    model1 = LogisticRegression()
    model1.fit(X,y)
    val = model.predict(valTest)
    return y_pred, y_test, y1_test, val

# %%
def logRegressionScaled(data, cutoff):
    data = data.drop(columns = 'time')
    test = data.drop(columns = ['Name', 'Symbol'])
    
    valTest = test.iloc[0:1, :]
    test = test.dropna()
    winner = test['% 6 hour diff'] > cutoff
    y1 = test['% 6 hour diff']
    test = test.dropna()
    scaler = StandardScaler() 
    test = scaler.fit_transform(test)
    
    X = test[:,:8]
    
#     X = test.drop(columns = ['% 6 hour diff', '6 hour diff'])
    valTest = valTest.drop(columns = ['% 6 hour diff', '6 hour diff'])
    
    y = winner
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)
    X1_train, X1_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.5, random_state=42)
    model = LogisticRegression()
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    
    
    model1 = LogisticRegression()
    model1.fit(X,y)
    val = model.predict(valTest)
    return y_pred, y_test, y1_test, val

# %%
p, t, per, act= logRegression(df, 2)
p

# %%
act[0]

# %%
metrics.accuracy_score(t, p)

# %%
df.iloc[1, :]

# %%
bch = df[df['Symbol'] == 'BCH-USD']
ltc = df[df['Symbol'] == 'LTC-USD']
zec = df[df['Symbol'] == 'ZEC-USD']
xrp = df[df['Symbol'] == 'XRP-USD']
xmr = df[df['Symbol'] == 'XMR-USD']
neo = df[df['Symbol'] == 'NEO-USD']
dash = df[df['Symbol'] == 'DASH-USD']
xlm = df[df['Symbol'] == 'XLM-USD']
bsv = df[df['Symbol'] == 'BSV-USD']
eth = df[df['Symbol'] == 'ETH-USD']
btc = df[df['Symbol'] == 'BTC-USD']

# %%
df[df['Symbol'] == 'ETH-USD'].head(10)

# %%
eth

# %%
frames = [eth,btc,bsv, bch, ltc]
#  bsv, btc, bch, ltc]

# %%
times = eth['time']
times

# %%
result = pd.DataFrame(columns = ['Symbol', 'cutoff', 'accuracy', 'over cutoff'])
for frame in frames:
    sym = list(frame['Symbol'])[0]
    for i in np.arange(0,10, .05):
        try:
            p, t, per, act = logRegressionScaled(frame, i)
            acc = metrics.accuracy_score(t, p)
            act = act[0]
            result = result.append({"Symbol" : sym,
                                            'cutoff': i, 
                                            "accuracy": acc, 
                                            "over cutoff": act}, ignore_index=True)
        except:
            continue

# %%
result[(result['over cutoff']) & (result['Symbol'] == 'ETH-USD')].sort_values('cutoff', ascending = False).head(40)

# %%
eth

# %%
pd.DataFrame(result[result['over cutoff']].groupby('Symbol')['cutoff'].max())

# %%
for a in range(10):
    eth = df[df['Symbol'] == 'ETH-USD'].iloc[a:]
    bsv = df[df['Symbol'] == 'BSV-USD'].iloc[a:]
    btc = df[df['Symbol'] == 'BTC-USD'].iloc[a:]
    bch = df[df['Symbol'] == 'BCH-USD'].iloc[a:]
    ltc = df[df['Symbol'] == 'LTC-USD'].iloc[a:]

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
# print(df)

# %%
display(result[result['over cutoff']].sort_values('cutoff', ascending = False))

# %%
p, t, per, act = logRegressionScaled(ltc, 9)
acc = metrics.accuracy_score(t, p)
acc
act

# %%
result[result['over cutoff']]

# %%
p

# %%
preds = pd.DataFrame({'y_pred':p, 'y_test':t, 'percents':per})
preds

# %%
preds[preds['y_pred']]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cm = metrics.confusion_matrix(t,p)
cax = ax.imshow(cm,cmap='gray', alpha = .4)
plt.title('Confusion matrix of the classifier')
plt.xlabel('Predicted')
plt.ylabel('True')
for i in range(2):
    for j in range(2):
        c = cm[j,i]
        ax.text(i, j, str(c), va='center', ha='center')
# plt.xticks(['True',, rotation=45)

# %%
preds[preds['y_pred'] != preds['y_test']].head(30)

# %%
scores = model.score(X_test, y_test)

# %%
test = ether.drop(columns = ['Name', 'Symbol'])
test = test.dropna()

# %%
X = test.drop(columns = ['6 hour diff'])
y = test['6 hour diff']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)
y_pred

# %%
preds = pd.DataFrame(y_pred, y_test).reset_index()
preds.columns = ['y_test', 'y_pred']
preds['abs diff'] = abs(preds['y_pred'] - preds['y_test'])
preds

# %%
preds[preds['y_pred'] > 4].head(60)

# %%
metrics.r2_score(y_test, y_pred)
